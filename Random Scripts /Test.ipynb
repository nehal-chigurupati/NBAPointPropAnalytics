# %%
from nba_api.stats.static import teams

# %%
nba_teams = teams.get_teams()

# %%
cavs = [team for team in nba_teams if team['abbreviation'] == 'CLE']

# %%
cavs = cavs[0]

# %%
from nba_api.stats.endpoints import leaguegamefinder

# %%
gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=cavs['id'])

# %%
gamefinder

# %%
games_dict = gamefinder.get_normalized_dict()['LeagueGameFinderResults']

# %%
lastGame = games_dict[0]

# %%
from nba_api.stats.endpoints import playbyplay

# %%
pbp = playbyplay.PlayByPlay(lastGame['GAME_ID']).get_data_frames()[0]

# %%
pbp.head()

# %%
pbp.loc[pbp['EVENTMSGTYPE'] == 5].head()

# %%
eventMsgDescriptionToCode = {
    'FIELD_GOAL_MADE':1,
    'FIELD_GOAL_MISSED':2,
    'FREE_THROW_ATTEMPT':3,
    'REBOUND':4,
    'TURNOVER':5,
    'FOUL':6,
    'VIOLATION':7,
    'SUBSTITUTION':8,
    'TIMEOUT':9,
    'JUMP_BALL':10,
    'EJECTION':11,
    'PERIOD_BEGIN':12,
    'PERIOD_END':13,
    'INSTANT_REPLAY':18
}

codeToEventMsgDescription = dict(zip(eventMsgDescriptionToCode.values(), eventMsgDescriptionToCode.keys()))

# %%
class DescribeActions:
    def team_of_action(row):
        ret = ""
        if row['HOMEDESCRIPTION'] != None:
            ret = ret + 'Home,'
        if row['NEUTRALDESCRIPTION'] != None:
            ret = ret + "Neutral,"
        if row['VISITORDESCRIPTION'] != None:
            ret = ret + "Visitor,"
        return ret
    def get_action_type(row):
        eventMsgDescriptionToCode = {
            'FIELD_GOAL_MADE':1,
            'FIELD_GOAL_MISSED':2,
            'FREE_THROW_ATTEMPT':3,
            'REBOUND':4,
            'TURNOVER':5,
            'FOUL':6,
            'VIOLATION':7,
            'SUBSTITUTION':8,
            'TIMEOUT':9,
            'JUMP_BALL':10,
            'EJECTION':11,
            'PERIOD_BEGIN':12,
            'PERIOD_END':13,
            'INSTANT_REPLAY':18
        }
        codeToEventMsgDescription = dict(zip(eventMsgDescriptionToCode.values(), eventMsgDescriptionToCode.keys()))

        return codeToEventMsgDescription[row['EVENTMSGTYPE']]
        
    def parse_turnover(row):
        if "Turnover" in str(row['HOMEDESCRIPTION']):
            return "HOME_TURNOVER"
        elif "Turnover" in str(row['VISITORDESCRIPTION']):
            return "VISITOR_TURNOVER"

    def parse(row):
        if DescribeActions.get_action_type(row) == "TURNOVER":
            return DescribeActions.parse_turnover(row)
        else:
            return DescribeActions.team_of_action(row)

# %%
for index, row in pbp.iterrows():
    print("Index: " + str(index) + ", Action: " + str(codeToEventMsgDescription[row['EVENTMSGTYPE']]) + ", Team: " + DescribeActions.parse(row))
# Out:
# Index: 0, Action: PERIOD_BEGIN, Team: Neutral,
# Index: 1, Action: JUMP_BALL, Team: Home,
# Index: 2, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 3, Action: REBOUND, Team: Home,
# Index: 4, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 5, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 6, Action: REBOUND, Team: Home,
# Index: 7, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 8, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 9, Action: REBOUND, Team: Home,
# Index: 10, Action: FOUL, Team: Visitor,
# Index: 11, Action: FREE_THROW_ATTEMPT, Team: Home,
# Index: 12, Action: FREE_THROW_ATTEMPT, Team: Home,
# Index: 13, Action: REBOUND, Team: Visitor,
# Index: 14, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 15, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 16, Action: FOUL, Team: Home,
# Index: 17, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 18, Action: REBOUND, Team: Visitor,
# Index: 19, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 20, Action: TURNOVER, Team: HOME_TURNOVER
# Index: 21, Action: TURNOVER, Team: VISITOR_TURNOVER
# Index: 22, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 23, Action: REBOUND, Team: Home,
# Index: 24, Action: TURNOVER, Team: HOME_TURNOVER
# Index: 25, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 26, Action: REBOUND, Team: Visitor,
# Index: 27, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 28, Action: REBOUND, Team: Home,
# Index: 29, Action: FOUL, Team: Visitor,
# Index: 30, Action: FREE_THROW_ATTEMPT, Team: Home,
# Index: 31, Action: FREE_THROW_ATTEMPT, Team: Home,
# Index: 32, Action: FOUL, Team: Home,
# Index: 33, Action: FREE_THROW_ATTEMPT, Team: Visitor,
# Index: 34, Action: FREE_THROW_ATTEMPT, Team: Visitor,
# Index: 35, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 36, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 37, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 38, Action: REBOUND, Team: Visitor,
# Index: 39, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 40, Action: REBOUND, Team: Visitor,
# Index: 41, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 42, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 43, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 44, Action: REBOUND, Team: Home,
# Index: 45, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 46, Action: REBOUND, Team: Visitor,
# Index: 47, Action: TIMEOUT, Team: Home,
# Index: 48, Action: SUBSTITUTION, Team: Home,
# Index: 49, Action: SUBSTITUTION, Team: Visitor,
# Index: 50, Action: SUBSTITUTION, Team: Visitor,
# Index: 51, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 52, Action: REBOUND, Team: Visitor,
# Index: 53, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 54, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 55, Action: REBOUND, Team: Visitor,
# Index: 56, Action: SUBSTITUTION, Team: Home,
# Index: 57, Action: SUBSTITUTION, Team: Home,
# Index: 58, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 59, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 60, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 61, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 62, Action: TURNOVER, Team: VISITOR_TURNOVER
# Index: 63, Action: FOUL, Team: Home,
# Index: 64, Action: TURNOVER, Team: HOME_TURNOVER
# Index: 65, Action: SUBSTITUTION, Team: Visitor,
# Index: 66, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 67, Action: REBOUND, Team: Home,
# Index: 68, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 69, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 70, Action: REBOUND, Team: Home,
# Index: 71, Action: TURNOVER, Team: HOME_TURNOVER
# Index: 72, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 73, Action: REBOUND, Team: Home,
# Index: 74, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 75, Action: REBOUND, Team: Home,
# Index: 76, Action: TURNOVER, Team: HOME_TURNOVER
# Index: 77, Action: SUBSTITUTION, Team: Visitor,
# Index: 78, Action: SUBSTITUTION, Team: Visitor,
# Index: 79, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 80, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 81, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 82, Action: REBOUND, Team: Home,
# Index: 83, Action: TIMEOUT, Team: Visitor,
# Index: 84, Action: SUBSTITUTION, Team: Home,
# Index: 85, Action: SUBSTITUTION, Team: Home,
# Index: 86, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 87, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 88, Action: REBOUND, Team: Visitor,
# Index: 89, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 90, Action: REBOUND, Team: Home,
# Index: 91, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 92, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 93, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 94, Action: REBOUND, Team: Visitor,
# Index: 95, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 96, Action: REBOUND, Team: Home,
# Index: 97, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 98, Action: TURNOVER, Team: VISITOR_TURNOVER
# Index: 99, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 100, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 101, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 102, Action: REBOUND, Team: Home,
# Index: 103, Action: PERIOD_END, Team: Neutral,
# Index: 104, Action: PERIOD_BEGIN, Team: Neutral,
# Index: 105, Action: FOUL, Team: Home,
# Index: 106, Action: FREE_THROW_ATTEMPT, Team: Visitor,
# Index: 107, Action: FREE_THROW_ATTEMPT, Team: Visitor,
# Index: 108, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 109, Action: FOUL, Team: Home,
# Index: 110, Action: FREE_THROW_ATTEMPT, Team: Visitor,
# Index: 111, Action: REBOUND, Team: Visitor,
# Index: 112, Action: FREE_THROW_ATTEMPT, Team: Visitor,
# Index: 113, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 114, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 115, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 116, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 117, Action: FOUL, Team: Visitor,
# Index: 118, Action: SUBSTITUTION, Team: Visitor,
# Index: 119, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 120, Action: REBOUND, Team: Visitor,
# Index: 121, Action: FOUL, Team: Visitor,
# Index: 122, Action: TURNOVER, Team: VISITOR_TURNOVER
# Index: 123, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 124, Action: REBOUND, Team: Visitor,
# Index: 125, Action: FOUL, Team: Home,
# Index: 126, Action: FREE_THROW_ATTEMPT, Team: Visitor,
# Index: 127, Action: FREE_THROW_ATTEMPT, Team: Visitor,
# Index: 128, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 129, Action: FOUL, Team: Home,
# Index: 130, Action: SUBSTITUTION, Team: Home,
# Index: 131, Action: SUBSTITUTION, Team: Home,
# Index: 132, Action: SUBSTITUTION, Team: Home,
# Index: 133, Action: SUBSTITUTION, Team: Visitor,
# Index: 134, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 135, Action: REBOUND, Team: Home,
# Index: 136, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 137, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 138, Action: REBOUND, Team: Home,
# Index: 139, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 140, Action: TIMEOUT, Team: Visitor,
# Index: 141, Action: SUBSTITUTION, Team: Visitor,
# Index: 142, Action: SUBSTITUTION, Team: Visitor,
# Index: 143, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 144, Action: FOUL, Team: Visitor,
# Index: 145, Action: FREE_THROW_ATTEMPT, Team: Home,
# Index: 146, Action: REBOUND, Team: Home,
# Index: 147, Action: FREE_THROW_ATTEMPT, Team: Home,
# Index: 148, Action: REBOUND, Team: Visitor,
# Index: 149, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 150, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 151, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 152, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 153, Action: FIELD_GOAL_MISSED, Team: Home,Visitor,
# Index: 154, Action: REBOUND, Team: Visitor,
# Index: 155, Action: TURNOVER, Team: VISITOR_TURNOVER
# Index: 156, Action: SUBSTITUTION, Team: Home,
# Index: 157, Action: SUBSTITUTION, Team: Home,
# Index: 158, Action: SUBSTITUTION, Team: Home,
# Index: 159, Action: SUBSTITUTION, Team: Visitor,
# Index: 160, Action: FOUL, Team: Visitor,
# Index: 161, Action: SUBSTITUTION, Team: Visitor,
# Index: 162, Action: VIOLATION, Team: Visitor,
# Index: 163, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 164, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 165, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 166, Action: REBOUND, Team: Visitor,
# Index: 167, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 168, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 169, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 170, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 171, Action: REBOUND, Team: Visitor,
# Index: 172, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 173, Action: TIMEOUT, Team: Home,
# Index: 174, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 175, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 176, Action: FOUL, Team: Visitor,
# Index: 177, Action: FREE_THROW_ATTEMPT, Team: Home,
# Index: 178, Action: FREE_THROW_ATTEMPT, Team: Home,
# Index: 179, Action: FOUL, Team: Home,
# Index: 180, Action: FREE_THROW_ATTEMPT, Team: Visitor,
# Index: 181, Action: SUBSTITUTION, Team: Visitor,
# Index: 182, Action: SUBSTITUTION, Team: Visitor,
# Index: 183, Action: FREE_THROW_ATTEMPT, Team: Visitor,
# Index: 184, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 185, Action: REBOUND, Team: Visitor,
# Index: 186, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 187, Action: REBOUND, Team: Home,
# Index: 188, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 189, Action: REBOUND, Team: Visitor,
# Index: 190, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 191, Action: REBOUND, Team: Home,
# Index: 192, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 193, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 194, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 195, Action: REBOUND, Team: Visitor,
# Index: 196, Action: TURNOVER, Team: VISITOR_TURNOVER
# Index: 197, Action: FOUL, Team: Visitor,
# Index: 198, Action: FREE_THROW_ATTEMPT, Team: Home,
# Index: 199, Action: FREE_THROW_ATTEMPT, Team: Home,
# Index: 200, Action: REBOUND, Team: Home,
# Index: 201, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 202, Action: TURNOVER, Team: VISITOR_TURNOVER
# Index: 203, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 204, Action: REBOUND, Team: Visitor,
# Index: 205, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 206, Action: SUBSTITUTION, Team: Home,
# Index: 207, Action: SUBSTITUTION, Team: Visitor,
# Index: 208, Action: SUBSTITUTION, Team: Visitor,
# Index: 209, Action: FOUL, Team: Visitor,
# Index: 210, Action: INSTANT_REPLAY, Team: Neutral,
# Index: 211, Action: FREE_THROW_ATTEMPT, Team: Home,
# Index: 212, Action: REBOUND, Team: Home,
# Index: 213, Action: FREE_THROW_ATTEMPT, Team: Home,
# Index: 214, Action: SUBSTITUTION, Team: Home,
# Index: 215, Action: SUBSTITUTION, Team: Home,
# Index: 216, Action: SUBSTITUTION, Team: Visitor,
# Index: 217, Action: REBOUND, Team: Visitor,
# Index: 218, Action: PERIOD_END, Team: Neutral,
# Index: 219, Action: PERIOD_BEGIN, Team: Neutral,
# Index: 220, Action: FIELD_GOAL_MISSED, Team: Home,Visitor,
# Index: 221, Action: REBOUND, Team: Visitor,
# Index: 222, Action: FOUL, Team: Home,
# Index: 223, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 224, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 225, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 226, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 227, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 228, Action: REBOUND, Team: Home,
# Index: 229, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 230, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 231, Action: REBOUND, Team: Visitor,
# Index: 232, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 233, Action: TIMEOUT, Team: Home,
# Index: 234, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 235, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 236, Action: REBOUND, Team: Home,
# Index: 237, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 238, Action: REBOUND, Team: Visitor,
# Index: 239, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 240, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 241, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 242, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 243, Action: REBOUND, Team: Visitor,
# Index: 244, Action: TURNOVER, Team: VISITOR_TURNOVER
# Index: 245, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 246, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 247, Action: REBOUND, Team: Home,
# Index: 248, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 249, Action: REBOUND, Team: Home,
# Index: 250, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 251, Action: TIMEOUT, Team: Visitor,
# Index: 252, Action: SUBSTITUTION, Team: Visitor,
# Index: 253, Action: SUBSTITUTION, Team: Visitor,
# Index: 254, Action: FOUL, Team: Home,
# Index: 255, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 256, Action: REBOUND, Team: Home,
# Index: 257, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 258, Action: FOUL, Team: Home,
# Index: 259, Action: FREE_THROW_ATTEMPT, Team: Visitor,
# Index: 260, Action: FREE_THROW_ATTEMPT, Team: Visitor,
# Index: 261, Action: REBOUND, Team: Home,
# Index: 262, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 263, Action: REBOUND, Team: Visitor,
# Index: 264, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 265, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 266, Action: TIMEOUT, Team: Visitor,
# Index: 267, Action: SUBSTITUTION, Team: Home,
# Index: 268, Action: SUBSTITUTION, Team: Home,
# Index: 269, Action: SUBSTITUTION, Team: Visitor,
# Index: 270, Action: FOUL, Team: Home,
# Index: 271, Action: FREE_THROW_ATTEMPT, Team: Visitor,
# Index: 272, Action: FREE_THROW_ATTEMPT, Team: Visitor,
# Index: 273, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 274, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 275, Action: FOUL, Team: Visitor,
# Index: 276, Action: FOUL, Team: Visitor,
# Index: 277, Action: TIMEOUT, Team: Home,
# Index: 278, Action: INSTANT_REPLAY, Team: Neutral,
# Index: 279, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 280, Action: REBOUND, Team: Visitor,
# Index: 281, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 282, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 283, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 284, Action: REBOUND, Team: Home,
# Index: 285, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 286, Action: REBOUND, Team: Visitor,
# Index: 287, Action: FOUL, Team: Home,
# Index: 288, Action: FREE_THROW_ATTEMPT, Team: Visitor,
# Index: 289, Action: SUBSTITUTION, Team: Home,
# Index: 290, Action: SUBSTITUTION, Team: Home,
# Index: 291, Action: SUBSTITUTION, Team: Home,
# Index: 292, Action: SUBSTITUTION, Team: Visitor,
# Index: 293, Action: SUBSTITUTION, Team: Visitor,
# Index: 294, Action: FREE_THROW_ATTEMPT, Team: Visitor,
# Index: 295, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 296, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 297, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 298, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 299, Action: REBOUND, Team: Visitor,
# Index: 300, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 301, Action: FOUL, Team: Home,
# Index: 302, Action: SUBSTITUTION, Team: Visitor,
# Index: 303, Action: FREE_THROW_ATTEMPT, Team: Visitor,
# Index: 304, Action: REBOUND, Team: Home,
# Index: 305, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 306, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 307, Action: REBOUND, Team: Home,
# Index: 308, Action: FOUL, Team: Visitor,
# Index: 309, Action: FREE_THROW_ATTEMPT, Team: Home,
# Index: 310, Action: FREE_THROW_ATTEMPT, Team: Home,
# Index: 311, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 312, Action: REBOUND, Team: Home,
# Index: 313, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 314, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 315, Action: REBOUND, Team: Home,
# Index: 316, Action: FOUL, Team: Visitor,
# Index: 317, Action: FREE_THROW_ATTEMPT, Team: Home,
# Index: 318, Action: REBOUND, Team: Home,
# Index: 319, Action: FREE_THROW_ATTEMPT, Team: Home,
# Index: 320, Action: SUBSTITUTION, Team: Home,
# Index: 321, Action: SUBSTITUTION, Team: Home,
# Index: 322, Action: SUBSTITUTION, Team: Visitor,
# Index: 323, Action: REBOUND, Team: Home,
# Index: 324, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 325, Action: PERIOD_END, Team: Neutral,
# Index: 326, Action: INSTANT_REPLAY, Team: Neutral,
# Index: 327, Action: PERIOD_BEGIN, Team: Neutral,
# Index: 328, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 329, Action: REBOUND, Team: Visitor,
# Index: 330, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 331, Action: TURNOVER, Team: HOME_TURNOVER
# Index: 332, Action: FOUL, Team: Visitor,
# Index: 333, Action: TURNOVER, Team: VISITOR_TURNOVER
# Index: 334, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 335, Action: REBOUND, Team: Visitor,
# Index: 336, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 337, Action: REBOUND, Team: Home,
# Index: 338, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 339, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 340, Action: REBOUND, Team: Home,
# Index: 341, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 342, Action: REBOUND, Team: Home,
# Index: 343, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 344, Action: REBOUND, Team: Visitor,
# Index: 345, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 346, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 347, Action: REBOUND, Team: Visitor,
# Index: 348, Action: TURNOVER, Team: VISITOR_TURNOVER
# Index: 349, Action: FOUL, Team: Visitor,
# Index: 350, Action: FREE_THROW_ATTEMPT, Team: Home,
# Index: 351, Action: FREE_THROW_ATTEMPT, Team: Home,
# Index: 352, Action: FOUL, Team: Home,
# Index: 353, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 354, Action: REBOUND, Team: Visitor,
# Index: 355, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 356, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 357, Action: REBOUND, Team: Visitor,
# Index: 358, Action: FOUL, Team: Home,
# Index: 359, Action: SUBSTITUTION, Team: Home,
# Index: 360, Action: SUBSTITUTION, Team: Home,
# Index: 361, Action: SUBSTITUTION, Team: Home,
# Index: 362, Action: SUBSTITUTION, Team: Home,
# Index: 363, Action: INSTANT_REPLAY, Team: Neutral,
# Index: 364, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 365, Action: REBOUND, Team: Home,
# Index: 366, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 367, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 368, Action: REBOUND, Team: Visitor,
# Index: 369, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 370, Action: REBOUND, Team: Visitor,
# Index: 371, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 372, Action: TURNOVER, Team: HOME_TURNOVER
# Index: 373, Action: FOUL, Team: Home,
# Index: 374, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 375, Action: REBOUND, Team: Visitor,
# Index: 376, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 377, Action: FOUL, Team: Home,
# Index: 378, Action: TURNOVER, Team: HOME_TURNOVER
# Index: 379, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 380, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 381, Action: FOUL, Team: Visitor,
# Index: 382, Action: TIMEOUT, Team: Home,
# Index: 383, Action: SUBSTITUTION, Team: Home,
# Index: 384, Action: FREE_THROW_ATTEMPT, Team: Home,
# Index: 385, Action: FIELD_GOAL_MISSED, Team: Home,Visitor,
# Index: 386, Action: REBOUND, Team: Home,
# Index: 387, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 388, Action: REBOUND, Team: Visitor,
# Index: 389, Action: FOUL, Team: Home,
# Index: 390, Action: TIMEOUT, Team: Visitor,
# Index: 391, Action: INSTANT_REPLAY, Team: Neutral,
# Index: 392, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 393, Action: TURNOVER, Team: HOME_TURNOVER
# Index: 394, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 395, Action: REBOUND, Team: Visitor,
# Index: 396, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 397, Action: FIELD_GOAL_MISSED, Team: Home,Visitor,
# Index: 398, Action: REBOUND, Team: Home,
# Index: 399, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 400, Action: TURNOVER, Team: VISITOR_TURNOVER
# Index: 401, Action: FOUL, Team: Visitor,
# Index: 402, Action: FREE_THROW_ATTEMPT, Team: Home,
# Index: 403, Action: FREE_THROW_ATTEMPT, Team: Home,
# Index: 404, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 405, Action: REBOUND, Team: Visitor,
# Index: 406, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 407, Action: REBOUND, Team: Home,
# Index: 408, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 409, Action: REBOUND, Team: Visitor,
# Index: 410, Action: FIELD_GOAL_MISSED, Team: Home,Visitor,
# Index: 411, Action: REBOUND, Team: Visitor,
# Index: 412, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 413, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 414, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 415, Action: TURNOVER, Team: HOME_TURNOVER
# Index: 416, Action: SUBSTITUTION, Team: Visitor,
# Index: 417, Action: SUBSTITUTION, Team: Visitor,
# Index: 418, Action: SUBSTITUTION, Team: Visitor,
# Index: 419, Action: SUBSTITUTION, Team: Visitor,
# Index: 420, Action: SUBSTITUTION, Team: Visitor,
# Index: 421, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 422, Action: REBOUND, Team: Home,
# Index: 423, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 424, Action: REBOUND, Team: Visitor,
# Index: 425, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 426, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 427, Action: FOUL, Team: Visitor,
# Index: 428, Action: FREE_THROW_ATTEMPT, Team: Home,
# Index: 429, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 430, Action: REBOUND, Team: Home,
# Index: 431, Action: FIELD_GOAL_MADE, Team: Home,
# Index: 432, Action: FIELD_GOAL_MISSED, Team: Visitor,
# Index: 433, Action: REBOUND, Team: Home,
# Index: 434, Action: SUBSTITUTION, Team: Home,
# Index: 435, Action: SUBSTITUTION, Team: Home,
# Index: 436, Action: SUBSTITUTION, Team: Home,
# Index: 437, Action: SUBSTITUTION, Team: Home,
# Index: 438, Action: SUBSTITUTION, Team: Home,
# Index: 439, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 440, Action: REBOUND, Team: Visitor,
# Index: 441, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 442, Action: FIELD_GOAL_MISSED, Team: Home,
# Index: 443, Action: REBOUND, Team: Visitor,
# Index: 444, Action: FIELD_GOAL_MADE, Team: Visitor,
# Index: 445, Action: PERIOD_END, Team: Neutral,
