# %%
from nba_api.stats.static import teams
import pandas as pd

# %%
celtics = [team for team in teams.get_teams() if team['abbreviation'] == 'BOS'][0]

# %%
celtics
# Out:
# {'id': 1610612738,
#  'full_name': 'Boston Celtics',
#  'abbreviation': 'BOS',
#  'nickname': 'Celtics',
#  'city': 'Boston',
#  'state': 'Massachusetts',
#  'year_founded': 1946}

# %%
celtics_id = celtics["id"]

# %%
from nba_api.stats.endpoints import leaguegamefinder

# %%
gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=celtics_id)

# %%
games = gamefinder.get_data_frames()[0]

# %%
games.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION       TEAM_NAME     GAME_ID  \
# 0     22023  1610612738               BOS  Boston Celtics  0022300188
# 1     22023  1610612738               BOS  Boston Celtics  0022300174
# 2     22023  1610612738               BOS  Boston Celtics  0022300010
# 3     22023  1610612738               BOS  Boston Celtics  0022300159
# 4     22023  1610612738               BOS  Boston Celtics  0022300154
#
#     GAME_DATE      MATCHUP    WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 0  2023-11-13  BOS vs. NYK  None  109   40  ...   0.750     3    13   16   11
# 1  2023-11-11  BOS vs. TOR     W  242  117  ...   0.615     5    41   46   30
# 2  2023-11-10  BOS vs. BKN     W  241  121  ...   0.714    17    35   52   29
# 3  2023-11-08    BOS @ PHI     L  241  103  ...   0.842     9    34   43   28
# 4  2023-11-06    BOS @ MIN     L  265  109  ...   0.765    11    34   45   20
#
#    STL  BLK  TOV  PF  PLUS_MINUS
# 0    0    1    4   6         0.8
# 1    1    4   12  14        23.0
# 2    5    3    7  13        14.0
# 3    8    6   12  13        -3.0
# 4   13    2   16  26        -5.0
#
# [5 rows x 28 columns]

# %%
games.groupby(games.SEASON_ID.str[-4:])[['GAME_ID']].count().loc['2015':]
# Out:
#            GAME_ID
# SEASON_ID
# 2015           103
# 2016           115
# 2017           113
# 2018           101
# 2019           102
# 2020            80
# 2021           115
# 2022           111
# 2023            20

# %%
games_1718 = games[games.SEASON_ID.str[-4:] == '2017']

# %%
games_1718.head()
# Out:
#     SEASON_ID     TEAM_ID TEAM_ABBREVIATION       TEAM_NAME     GAME_ID  \
# 529     42017  1610612738               BOS  Boston Celtics  0041700307
# 530     42017  1610612738               BOS  Boston Celtics  0041700306
# 531     42017  1610612738               BOS  Boston Celtics  0041700305
# 532     42017  1610612738               BOS  Boston Celtics  0041700304
# 533     42017  1610612738               BOS  Boston Celtics  0041700303
#
#       GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 529  2018-05-27  BOS vs. CLE  L  240   79  ...   0.737    11    31   42   18
# 530  2018-05-25    BOS @ CLE  L  241   99  ...   0.550     5    26   31   25
# 531  2018-05-23  BOS vs. CLE  W  240   96  ...   0.913     7    38   45   18
# 532  2018-05-21    BOS @ CLE  L  239  102  ...   0.767     9    28   37   21
# 533  2018-05-19    BOS @ CLE  L  240   86  ...   0.786     6    28   34   16
#
#      STL  BLK  TOV  PF  PLUS_MINUS
# 529    6    0    5  20        -8.0
# 530    5    2   13  18       -10.0
# 531   10    6    8  19        13.0
# 532    9    3    9  26        -9.0
# 533    4    4   15  25       -30.0
#
# [5 rows x 28 columns]

# %%
raps_games_1718 = games_1718[games_1718.MATCHUP.str.contains('TOR')]
raps_games_1718.head()
# Out:
#     SEASON_ID     TEAM_ID TEAM_ABBREVIATION       TEAM_NAME     GAME_ID  \
# 552     22017  1610612738               BOS  Boston Celtics  0021701171
# 554     22017  1610612738               BOS  Boston Celtics  0021701140
# 575     22017  1610612738               BOS  Boston Celtics  0021700798
# 616     22017  1610612738               BOS  Boston Celtics  0021700188
#
#       GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 552  2018-04-04    BOS @ TOR  L  237   78  ...   0.893     8    35   43   10
# 554  2018-03-31  BOS vs. TOR  W  240  110  ...   0.852     8    33   41   19
# 575  2018-02-06    BOS @ TOR  L  240   91  ...   0.750     9    29   38   21
# 616  2017-11-12  BOS vs. TOR  W  239   95  ...   0.789    15    31   46   24
#
#      STL  BLK  TOV  PF  PLUS_MINUS
# 552    7    3   16  16       -18.0
# 554    6    3    5  23        11.0
# 575    3    3   17  19       -20.0
# 616    9    2   14  18         1.0
#
# [4 rows x 28 columns]

# %%
last_raps_game = raps_games_1718.sort_values('GAME_DATE').iloc[-1]

# %%
last_raps_game
# Out:
# SEASON_ID                     22017
# TEAM_ID                  1610612738
# TEAM_ABBREVIATION               BOS
# TEAM_NAME            Boston Celtics
# GAME_ID                  0021701171
# GAME_DATE                2018-04-04
# MATCHUP                   BOS @ TOR
# WL                                L
# MIN                             237
# PTS                              78
# FGM                              25
# FGA                              75
# FG_PCT                        0.333
# FG3M                              3
# FG3A                             22
# FG3_PCT                       0.136
# FTM                              25
# FTA                              28
# FT_PCT                        0.893
# OREB                              8
# DREB                             35
# REB                              43
# AST                              10
# STL                               7
# BLK                               3
# TOV                              16
# PF                               16
# PLUS_MINUS                    -18.0
# Name: 552, dtype: object

# %%
game_id = last_raps_game.GAME_ID

# %%
game_id
# Out:
# '0021701171'

# %%
result = leaguegamefinder.LeagueGameFinder()

# %%
all_games = result.get_data_frames()[0]

# %%
full_game = all_games[all_games.GAME_ID == game_id]

# %%
full_game = all_games[all_games.GAME_ID == game_id]

# %%
full_game
# Out:
# Empty DataFrame
# Columns: [SEASON_ID, TEAM_ID, TEAM_ABBREVIATION, TEAM_NAME, GAME_ID, GAME_DATE, MATCHUP, WL, MIN, PTS, FGM, FGA, FG_PCT, FG3M, FG3A, FG3_PCT, FTM, FTA, FT_PCT, OREB, DREB, REB, AST, STL, BLK, TOV, PF, PLUS_MINUS]
# Index: []
#
# [0 rows x 28 columns]

# %%
from nba_api.stats.endpoints import playbyplayv2

# %%
pbp = playbyplayv2.PlayByPlayV2(game_id)

# %%
pbp = pbp.get_data_frames()[0]

# %%
pbp.head()
# Out:
#       GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 0  0021701171         2            12                   0       1
# 1  0021701171         4            10                   0       1
# 2  0021701171         7             2                   1       1
# 3  0021701171         8             4                   0       1
# 4  0021701171         9             2                  86       1
#
#   WCTIMESTRING PCTIMESTRING                                   HOMEDESCRIPTION  \
# 0      8:11 PM        12:00                                              None
# 1      8:11 PM        12:00  Jump Ball Valanciunas vs. Baynes: Tip to Anunoby
# 2      8:11 PM        11:38                        MISS DeRozan 21' Jump Shot
# 3      8:11 PM        11:36                                              None
# 4      8:12 PM        11:21                                              None
#
#                   NEUTRALDESCRIPTION  \
# 0  Start of 1st Period (8:11 PM EST)
# 1                               None
# 2                               None
# 3                               None
# 4                               None
#
#                           VISITORDESCRIPTION  ... PLAYER2_TEAM_NICKNAME  \
# 0                                       None  ...                  None
# 1                                       None  ...               Celtics
# 2                                       None  ...                  None
# 3                Tatum REBOUND (Off:0 Def:1)  ...                  None
# 4  MISS Horford 12' Turnaround Fadeaway Shot  ...                  None
#
#   PLAYER2_TEAM_ABBREVIATION  PERSON3TYPE  PLAYER3_ID PLAYER3_NAME  \
# 0                      None            0           0         None
# 1                       BOS            4     1628384   OG Anunoby
# 2                      None            0           0         None
# 3                      None            0           0         None
# 4                      None            0           0         None
#
#    PLAYER3_TEAM_ID PLAYER3_TEAM_CITY PLAYER3_TEAM_NICKNAME  \
# 0              NaN              None                  None
# 1     1.610613e+09           Toronto               Raptors
# 2              NaN              None                  None
# 3              NaN              None                  None
# 4              NaN              None                  None
#
#   PLAYER3_TEAM_ABBREVIATION  VIDEO_AVAILABLE_FLAG
# 0                      None                     0
# 1                       TOR                     1
# 2                      None                     1
# 3                      None                     1
# 4                      None                     1
#
# [5 rows x 34 columns]
